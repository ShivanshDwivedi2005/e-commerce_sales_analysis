# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# the file we are going to work is .zip file so first we need to change it in xlsx file

# %%
import zipfile

# Path to the ZIP file
zip_path = "Superstore_USA.xlsx.zip"
extract_path = "./"  # Directory to extract files to

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("File extracted successfully!")
# Out:
# File extracted successfully!

# %%
import pandas as pd

# Path to the extracted Excel file
excel_file_path = "Superstore_USA.xlsx"

# Load the data into a DataFrame
data = pd.read_excel(excel_file_path)

# Display the first few rows
print(data.head())
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
data.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %%
data.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %% [markdown]
# there are 72 rows in which product base margin is missing now i need to fill that cells with mean

# %%
data["Product Base Margin"] = data["Product Base Margin"].fillna(data["Product Base Margin"].mean())

# %%
data.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
ax = sns.countplot(x = 'Order Priority',data = data,hue = 'Discount')
plt.title("order Priority count")
plt.show()
data['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
data['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %% [markdown]
# the above data show that theri are two critical because of an extra space in second critical now we need to replace 'Critical ' with 'Critical'

# %%
data = data.replace("Critical ","Critical")
data['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical'], dtype=object)

# %%
data['Discount'].value_counts()
# Out:
# Discount
# 0.01    898
# 0.03    882
# 0.05    879
# 0.09    871
# 0.02    870
# 0.04    861
# 0.08    850
# 0.00    848
# 0.10    838
# 0.06    821
# 0.07    803
# 0.11      1
# 0.17      1
# 0.16      1
# 0.25      1
# 0.21      1
# Name: count, dtype: int64

# %%
data['Product Category'].value_counts()
# Out:
# Product Category
# Office Supplies    5181
# Technology         2312
# Furniture          1933
# Name: count, dtype: int64

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
plt.figure(figsize = (22,8))
ax = sns.countplot(x = 'Unit Price', data = df)
plt.title('total sales count per unit price')
plt.show()

# %%
from matplotlib import style
import matplotlib.pyplot as plt
style.use('ggplot')
unit_price_counts = df['Unit Price'].value_counts()
plt.scatter(unit_price_counts.index, unit_price_counts.values)
plt.xlabel('Unit Price')
plt.ylabel('Count')
plt.title('Unit Price vs Count')
plt.show()

# %% [markdown]
# * most of the projects are of less price ranges within 1000

# %%
style.use('ggplot')
unit_price_counts = df['Shipping Cost'].value_counts()
plt.scatter(unit_price_counts.index, unit_price_counts.values)
plt.xlabel('Shipping Cost')
plt.ylabel('Count')
plt.title('Unit Price vs Count')
plt.show()

# %% [markdown]
# * generally people prefer to order the products with less shipping cost

# %%
plt.figure(figsize=(16,8))
ax = sns.countplot(x = 'Product Category', data = df,hue = 'Product Sub-Category')
plt.title('Product Category count')
plt.show()

# %% [markdown]
# *  most of the products are office supplies related followed by technology

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(x = 'Product Container', data = df)
plt.title('Product Container count')
plt.show()

# %%
plt.figure(figsize=(16,8))
ax = sns.histplot(x = 'Product Base Margin', data = df)
ax.bar_label(ax.containers[0])
plt.title('Product base margin count')
plt.show()

# %%
df['Product Base Margin']
# Out:
# 0       0.36
# 1       0.54
# 2       0.37
# 3       0.56
# 4       0.59
#         ...
# 9421    0.40
# 9422    0.54
# 9423    0.71
# 9424    0.65
# 9425    0.38
# Name: Product Base Margin, Length: 9426, dtype: float64

# %%
plt.figure(figsize=(18,8))
ax = sns.countplot(x = 'Region', data = df,hue = 'Product Category')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
plt.title('Product Region count')
plt.show()

# %%
plt.figure(figsize=(22,8))
ax = sns.countplot(x = 'State or Province', data = df,hue = 'Product Category')
ax.tick_params(rotation = 85)
plt.title('Product Category count')
plt.show()

# %%
sns.countplot(x = 'Profit', data = df)
plt.title('profit count')
plt.show()
